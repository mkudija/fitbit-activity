# %% [markdown]
# # Analyze Fitbit Data With Python and Pandas
# First we import the data into a pandas dataframe, and take a glance at the data format.

# %%
import pandas as pd
steps = pd.read_csv("fitbit_steps.csv",index_col='Date')
sleep = pd.read_csv("fitbit_sleep.csv",index_col='Date')
# can improve how we read this in: http://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html
steps.head()
# Out:
#            Calories Burned  Steps  Distance  Floors  Minutes Sedentary  \
# Date
# 3/6/2016              3647  21066     10.40     110                525
# 3/7/2016              2872  12925      6.23      15                707
# 3/8/2016              2837  11698      5.64      11                844
# 3/9/2016              3032  11637      8.87      13                743
# 3/10/2016             2882  12453      6.00      16                745
#
#            Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# Date
# 3/6/2016                      185                     63                   93
# 3/7/2016                      130                     38                   39
# 3/8/2016                      185                      5                   29
# 3/9/2016                      220                     32                   17
# 3/10/2016                     180                      5                   36
#
#            Activity Calories
# Date
# 3/6/2016                2115
# 3/7/2016                1209
# 3/8/2016                1176
# 3/9/2016                1427
# 3/10/2016               1238

# %% [markdown]
# The `dataframe.describe()` method provides some useful summary statistics:

# %%
steps.describe()
# Out:
#        Calories Burned         Steps    Distance      Floors  \
# count       179.000000    179.000000  179.000000  179.000000
# mean       2889.726257   9569.351955    4.687486   22.491620
# std         490.516316   4713.578219    2.316243   48.411899
# min        1843.000000      0.000000    0.000000    0.000000
# 25%        2691.500000   7242.000000    3.490000    8.000000
# 50%        2917.000000  10139.000000    4.940000   15.000000
# 75%        3108.500000  12179.500000    5.905000   24.000000
# max        4716.000000  34382.000000   16.580000  588.000000
#
#        Minutes Sedentary  Minutes Lightly Active  Minutes Fairly Active  \
# count         179.000000              179.000000             179.000000
# mean          835.525140              181.636872              21.329609
# std           247.462704               76.891628              21.502489
# min           306.000000                0.000000               0.000000
# 25%           692.500000              161.500000               5.500000
# 50%           767.000000              198.000000              17.000000
# 75%           897.500000              228.500000              29.000000
# max          1440.000000              340.000000             128.000000
#
#        Minutes Very Active  Activity Calories
# count           179.000000         179.000000
# mean             27.720670        1224.039106
# std              29.980334         608.757515
# min               0.000000           0.000000
# 25%               6.500000         953.000000
# 50%              21.000000        1278.000000
# 75%              40.000000        1501.500000
# max             186.000000        3507.000000

# %% [markdown]
# I know there are some days that I did not wear my Fitbit so no activity was recorded. Likewise, there may be some days where I only wore it for a small portion of the day. Let's look at all records with less than 1000 steps:

# %%
steps[steps.Steps < 1000]
# Out:
#            Calories Burned  Steps  Distance  Floors  Minutes Sedentary  \
# Date
# 5/12/2016             1858     44      0.02       0               1042
# 6/7/2016              1843      0      0.00       0               1440
# 6/8/2016              1845      0      0.00       0               1440
# 6/13/2016             1843      0      0.00       0               1440
# 6/14/2016             1960    451      0.22       0               1311
# 7/18/2016             1872    113      0.05       0               1357
# 7/23/2016             1899    347      0.17       0               1046
# 7/28/2016             1843      0      0.00       0               1440
# 7/29/2016             1843      0      0.00       0               1440
# 7/30/2016             1843      0      0.00       0               1440
# 7/31/2016             1843      0      0.00       0               1440
# 8/1/2016              1973    994      0.50       0               1418
# 8/2/2016              1843      0      0.00       0               1440
# 8/6/2016              1878     80      0.04       0               1009
# 8/20/2016             1892    246      0.12       0               1045
# 8/31/2016             1865     61      0.03       0                876
#
#            Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# Date
# 5/12/2016                       5                      0                    0
# 6/7/2016                        0                      0                    0
# 6/8/2016                        0                      0                    0
# 6/13/2016                       0                      0                    0
# 6/14/2016                       8                      4                   10
# 7/18/2016                       9                      0                    0
# 7/23/2016                      13                      0                    0
# 7/28/2016                       0                      0                    0
# 7/29/2016                       0                      0                    0
# 7/30/2016                       0                      0                    0
# 7/31/2016                       0                      0                    0
# 8/1/2016                       22                      0                    0
# 8/2/2016                        0                      0                    0
# 8/6/2016                        8                      0                    0
# 8/20/2016                      18                      0                    0
# 8/31/2016                       7                      0                    0
#
#            Activity Calories
# Date
# 5/12/2016                 16
# 6/7/2016                   0
# 6/8/2016                   0
# 6/13/2016                  0
# 6/14/2016                141
# 7/18/2016                 39
# 7/23/2016                 65
# 7/28/2016                  0
# 7/29/2016                  0
# 7/30/2016                  0
# 7/31/2016                  0
# 8/1/2016                 157
# 8/2/2016                   0
# 8/6/2016                  27
# 8/20/2016                 61
# 8/31/2016                 22

# %% [markdown]
# As suspected, there are a number of records with no (or lacking) data. We will exclude these outliers. To verify they are no longer in the dataframe, we print out a few rows around item 167 (8/20/2016) that was removed.

# %%
steps = steps[steps.Steps > 1000]
steps.ix[165:169]
# NEEDS UPDATE NOW
# Out:
# Empty DataFrame
# Columns: [Calories Burned, Steps, Distance, Floors, Minutes Sedentary, Minutes Lightly Active, Minutes Fairly Active, Minutes Very Active, Activity Calories]
# Index: []

# %% [markdown]
# Likewise, we might have some outliers on the high end. We use the `sort_values` method to sort the Steps column from highest to lowest, and we specify that we want to see the top 10 results in the `head` method.

# %%
steps.sort_values(['Steps'], ascending=[0]).head(10)

# %% [markdown]
# Taking a look here, the first entry looks like quite an outlier that may through some trending analysis off. Let's remove this entry.

# %%
steps = steps[steps.Steps < 30000]

# %% [markdown]
# ### Adding A Summary Column
# We notice that we have minutes sedentary and than minutes active by various levels of activity. It might be useful to know *total* minutes active, so we create a new column that represents this value.

# %%
steps['Total Minutes Active'] = steps['Minutes Lightly Active'] + steps['Minutes Fairly Active'] + steps['Minutes Very Active']
steps.head()

# %% [markdown]
# Now that we have cleaned up our data and taken an initial look, let's take a quick peek at steps and floors visually.
#
# Now that we include the `%matplotlib inline` command so that figures appear in the Jupyter notebook.

# %%
# %matplotlib inline
import matplotlib
ts = steps['Steps']
ts.plot()
# improve plotting with this: http://earthpy.org/pandas-basics.html

# %% [markdown]
# ### Secondary y-axis
# If we want, we can include additional information, in this case the number of floors climbed. Since this is a much smaller number than steps, we will plot it on a secondary y-axis.

# %%
# %matplotlib inline
steps.Steps.plot()
steps.Floors.plot(secondary_y=True)

# %% [markdown]
# ### Scatter Matrix Plot
# Pandas has a useful feature called Scatter Matrix Plot for visualizing linear correlations between variables in your dataframe. We select the columns (variables) to include. The `'kde'` diagonal gives us a density plot for each variable.

# %%
from pandas.tools.plotting import scatter_matrix
scatter_matrix(steps[['Steps', 'Floors', 'Minutes Sedentary', 'Total Minutes Active']], diagonal='kde')
